# %%
from SMABacktester import SMABacktester as SMA

# %%
instrument = "EUR_USD"

trader = SMA(file= "EURUSD_2018-12-01_2021-03-26", bar_length ="20min", SMA_S = 50, SMA_L = 200,  start = "2018-12-01", end = "2021-03-26", tc = 0.00007)

# %%
trader.data
# Out:
#                               open     high      low    close   returns  \
# time
# 2018-12-05 17:00:00+00:00  1.13494  1.13499  1.13494  1.13494  0.000335
# 2018-12-05 17:20:00+00:00  1.13512  1.13512  1.13505  1.13505  0.000097
# 2018-12-05 17:40:00+00:00  1.13530  1.13530  1.13506  1.13508  0.000026
# 2018-12-05 18:00:00+00:00  1.13499  1.13508  1.13492  1.13502 -0.000053
# 2018-12-05 18:20:00+00:00  1.13482  1.13482  1.13474  1.13478 -0.000211
# ...                            ...      ...      ...      ...       ...
# 2021-03-25 22:20:00+00:00  1.17690  1.17697  1.17690  1.17696  0.000042
# 2021-03-25 22:40:00+00:00  1.17713  1.17713  1.17713  1.17713  0.000144
# 2021-03-25 23:00:00+00:00  1.17730  1.17739  1.17728  1.17737  0.000204
# 2021-03-25 23:20:00+00:00  1.17736  1.17740  1.17736  1.17739  0.000017
# 2021-03-25 23:40:00+00:00  1.17756  1.17756  1.17750  1.17752  0.000110
#
#                               SMA_S     SMA_L
# time
# ...

# %%
trader.test_strategy()
# Out:
# (1.237873, 0.208204)

# %%
trader.plot_results()

# %%
trader.optimize_parameters((25, 50, 1), (100, 200, 1))
# Out:
# (array([ 26., 184.]), 1.237873)
